# %%
import requests
import time
import urllib.request
import json

url = "http://api.open-notify.org/iss-now.json"
data_count = 100 #used chat gpt for this
interval = 10 #used chat gpt for this, will wait approx 16 minutes to get 100 data

data = []
for _ in range(data_count):
    response = requests.get(url)
    if response.status_code == 200:
        obj = json.loads(response.content.decode())
        data_point = {
            "timestamp": obj['timestamp'],
            "latitude": float(obj['iss_position']['latitude']),
            "longitude": float(obj['iss_position']['longitude'])
        }
        data.append(data_point)
    time.sleep(interval)
data
#for data_point in data:
    #print("timestamp:", data_point['timestamp'])
    #print("latitude:", data_point['latitude'], ", longitude:", data_point['longitude'])
    #print()  # Add an empty line between data points
# Out:
# [{'timestamp': 1688877446, 'latitude': 17.7004, 'longitude': 28.5911},
#  {'timestamp': 1688877457, 'latitude': 17.1842, 'longitude': 29.0104},
#  {'timestamp': 1688877467, 'latitude': 16.667, 'longitude': 29.427},
#  {'timestamp': 1688877478, 'latitude': 16.1486, 'longitude': 29.8413},
#  {'timestamp': 1688877488, 'latitude': 15.6293, 'longitude': 30.2531},
#  {'timestamp': 1688877499, 'latitude': 15.1091, 'longitude': 30.6626},
#  {'timestamp': 1688877509, 'latitude': 14.588, 'longitude': 31.0699},
#  {'timestamp': 1688877520, 'latitude': 14.0661, 'longitude': 31.475},
#  {'timestamp': 1688877530, 'latitude': 13.5433, 'longitude': 31.878},
#  {'timestamp': 1688877541, 'latitude': 13.0199, 'longitude': 32.279},
#  {'timestamp': 1688877551, 'latitude': 12.4956, 'longitude': 32.6782},
#  {'timestamp': 1688877562, 'latitude': 11.9707, 'longitude': 33.0755},
#  {'timestamp': 1688877572, 'latitude': 11.445, 'longitude': 33.4712},
#  {'timestamp': 1688877583, 'latitude': 10.9187, 'longitude': 33.8652},
#  {'timestamp': 1688877593, 'latitude': 10.3919, 'longitude': 34.2576},
#  {'timestamp': 1688877604, 'latitude': 9.8643, 'longitude': 34.6486},
#  {'timestamp': 1688877614, 'latitude': 9.3363, 'longitude': 35.0381},
#  {'timestamp': 1688877625, 'latitude': 8.8077, 'longitude': 35.4264},
#  {'timestamp': 1688877635, 'latitude': 8.2786, 'longitude': 35.8134},
#  {'timestamp': 1688877646, 'latitude': 7.749, 'longitude': 36.1993},
#  {'timestamp': 1688877656, 'latitude': 7.2191, 'longitude': 36.5841},
#  {'timestamp': 1688877667, 'latitude': 6.6888, 'longitude': 36.9678},
#  {'timestamp': 1688877677, 'latitude': 6.1581, 'longitude': 37.3506},
#  {'timestamp': 1688877688, 'latitude': 5.6271, 'longitude': 37.7325},
#  {'timestamp': 1688877699, 'latitude': 5.0958, 'longitude': 38.1137},
#  {'timestamp': 1688877709, 'latitude': 4.5641, 'longitude': 38.4942},
#  {'timestamp': 1688877720, 'latitude': 4.0323, 'longitude': 38.874},
#  {'timestamp': 1688877730, 'latitude': 3.5003, 'longitude': 39.2532},
#  {'timestamp': 1688877741, 'latitude': 2.9679, 'longitude': 39.632},
#  {'timestamp': 1688877751, 'latitude': 2.4355, 'longitude': 40.0104},
#  {'timestamp': 1688878161, 'latitude': -18.1277, 'longitude': 55.2319},
#  {'timestamp': 1688878172, 'latitude': -18.6412, 'longitude': 55.6555},
#  {'timestamp': 1688878182, 'latitude': -19.1535, 'longitude': 56.0819},
#  {'timestamp': 1688878193, 'latitude': -19.6645, 'longitude': 56.5113},
#  {'timestamp': 1688878203, 'latitude': -20.1744, 'longitude': 56.9436},
#  {'timestamp': 1688878214, 'latitude': -20.6829, 'longitude': 57.3791},
#  {'timestamp': 1688878224, 'latitude': -21.1901, 'longitude': 57.8178},
#  {'timestamp': 1688878235, 'latitude': -21.6959, 'longitude': 58.2598},
#  {'timestamp': 1688878245, 'latitude': -22.2002, 'longitude': 58.7051},
#  {'timestamp': 1688878256, 'latitude': -22.703, 'longitude': 59.154},
#  {'timestamp': 1688878266, 'latitude': -23.2044, 'longitude': 59.6066},
#  {'timestamp': 1688878277, 'latitude': -23.7041, 'longitude': 60.0629},
#  {'timestamp': 1688878287, 'latitude': -24.2022, 'longitude': 60.523},
#  {'timestamp': 1688878298, 'latitude': -24.6986, 'longitude': 60.987},
#  {'timestamp': 1688878308, 'latitude': -25.1933, 'longitude': 61.4551},
#  {'timestamp': 1688878319, 'latitude': -25.6864, 'longitude': 61.9275},
#  {'timestamp': 1688878329, 'latitude': -26.1774, 'longitude': 62.404},
#  {'timestamp': 1688878340, 'latitude': -26.6665, 'longitude': 62.8849},
#  {'timestamp': 1688878351, 'latitude': -27.1769, 'longitude': 63.3936},
#  {'timestamp': 1688878361, 'latitude': -27.6389, 'longitude': 63.8604},
#  {'timestamp': 1688878371, 'latitude': -28.122, 'longitude': 64.3552},
#  {'timestamp': 1688878382, 'latitude': -28.6029, 'longitude': 64.8549},
#  {'timestamp': 1688878393, 'latitude': -29.0817, 'longitude': 65.3595},
#  {'timestamp': 1688878403, 'latitude': -29.5582, 'longitude': 65.8693},
#  {'timestamp': 1688878414, 'latitude': -30.0323, 'longitude': 66.3843},
#  {'timestamp': 1688878424, 'latitude': -30.504, 'longitude': 66.9045},
#  {'timestamp': 1688878435, 'latitude': -30.9733, 'longitude': 67.4303},
#  {'timestamp': 1688878445, 'latitude': -31.44, 'longitude': 67.9617},
#  {'timestamp': 1688878456, 'latitude': -31.9042, 'longitude': 68.4989},
#  {'timestamp': 1688878467, 'latitude': -32.3876, 'longitude': 69.068},
#  {'timestamp': 1688878477, 'latitude': -32.8462, 'longitude': 69.6173},
#  {'timestamp': 1688878488, 'latitude': -33.3019, 'longitude': 70.1728}]

# %%
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

timestamps = [data_point['timestamp'] for data_point in data]
latitudes = [data_point['latitude'] for data_point in data]
longitudes = [data_point['longitude'] for data_point in data]

plt.plot(latitudes, longitudes)
plt.xlabel('Latitudes')
plt.ylabel('Longitudes')
plt.title('Location of the International Space Station')
plt.grid(True)

plt.show()

# %%
timestamps_count = len(timestamps)
print("Number of data points:", timestamps_count) #proof it is 100 in the data set
# Out:
# Number of data points: 100
